# %%
import numpy as np
from numpy import linalg as LA
import pandas as pd
import os

# %%
cwd = os.getcwd()
most = pd.read_csv(f"{cwd}/8-7_RT-zOGF_df.csv")
alpha_star_df = pd.read_csv(f"{cwd}/alpha_star_only_df.csv")

# %%
no_ct = most.drop('centr', axis=1)

# %%
star_as_alg = alpha_star_df.rename(columns={"alpha":"algorithm"})

# %%
star_as_alg["algorithm"] = '$\\alpha = \\alpha^*$'

# %%
big_df = pd.concat([most, star_as_alg])

# %%
big_df.to_csv(f"{cwd}/all_algs_10-1_df.csv")
